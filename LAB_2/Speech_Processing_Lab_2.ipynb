# %%
#A1
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

audio_path = r"C:\Users\gowth\Downloads\ai_sp.wav"
y, sr = librosa.load(audio_path)

derivative_1 = np.diff(y)
derivative_1 /= np.max(np.abs(derivative_1))

print("Playing First Derivative Signal:")
plt.figure(figsize=(10, 5))
librosa.display.waveshow(derivative_1)
plt.title('First Derivative of Audio Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Playing First Derivative Signal:

# %%
#Original
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y, sr=sr)
plt.title('ORIGINAL')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#A2

zero_crossings = np.where(np.diff(np.sign(derivative_1)))[0]
differences = np.diff(zero_crossings)
threshold = 1000
speech_regions = differences[differences > threshold]
silence_regions = differences[differences <= threshold]

average_length_speech = np.mean(speech_regions)
average_length_silence = np.mean(silence_regions)

print("Average length between consecutive zero crossings in speech regions:", average_length_speech)
print("Average length between consecutive zero crossings in silence regions:", average_length_silence)

plt.figure(figsize=(10, 5))
plt.plot(differences, label='All regions', color='black')
plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions', color='blue')
plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions', color='blue')
plt.title('Pattern of Zero Crossings')
plt.xlabel('Zero Crossing Difference')
plt.ylabel('Difference between Consecutive Zero Crossings')
plt.legend()
plt.show()

print("Pattern of Zero Crossings:")
print("All regions -", differences)
print("Speech regions -", speech_regions)
print("Silence regions -", silence_regions)
# Out:
# C:\Users\gowth\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\gowth\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\gowth\AppData\Local\Temp\ipykernel_20260\1980710066.py:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions', color='blue')
# C:\Users\gowth\AppData\Local\Temp\ipykernel_20260\1980710066.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
# ...

# %%
#A3

word_files_mine = ['lab_2_2.wav', 'lab_2_4.wav', 'lab2_1.wav', 'lab_2_5.wav', 'lab_2_3.wav']
word_files_team_mate = ['facebookmine.wav', 'twittermine.wav', 'whatsappmine.wav', 'snapchatmine.wav', 'instagrammine.wav']
words = ['whatsapp', 'facebook', 'instagram', 'twitter', 'snapchat']
word_lengths_mine = []
word_lengths_teammate = []

for word_file in word_files_mine:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_mine.append(length_seconds)

for word_file in word_files_team_mate:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_teammate.append(length_seconds)

print("Lengths of the spoken words MINE:", word_lengths_mine)
print("Lengths of the spoken words TeamMate:", word_lengths_teammate)

bar_width = 0.35
index = np.arange(len(words))
plt.figure(figsize=(12, 6))
plt.bar(index - bar_width/2, word_lengths_mine, bar_width, label='My Words', color='black')
plt.bar(index + bar_width/2, word_lengths_teammate, bar_width, label="Teammate's Words", color='red')
plt.xlabel('Words')
plt.ylabel('Length (seconds)')
plt.title('Comparison of Spoken Words Length')
plt.xticks(index, words)
plt.legend()

plt.show()
# Out:
# Lengths of the spoken words MINE: [1.9626666666666666, 1.6426666666666667, 1.8773333333333333, 2.026666666666667, 2.432]
# Lengths of the spoken words TeamMate: [2.304, 1.792, 2.2826666666666666, 2.0906666666666665, 1.92]

# %%
#A4

import librosa
import librosa.display
import matplotlib.pyplot as plt

statement, sr1 = librosa.load('record_out (5).wav')
question, sr2 = librosa.load('record_out.wav')

plt.figure(figsize=(10, 5))
librosa.display.waveshow(question, sr=sr2)
plt.title('QUESTION')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=sr1)
plt.title('STATEMENT')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
